# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np 
import pandas as pd

file_path = 'movie_data/chunk_1_with_info.csv'

df_movies = pd.read_csv(file_path)
print(df_movies['title'].head(20))
# Out:
# 0                      Summer of 85
# 1                        Free Birds
# 2                        Blood Work
# 3               Hiroshima Mon Amour
# 4                  A Bridge Too Far
# 5               Message in a Bottle
# 6     Barbie: Princess Charm School
# 7                      The Big Year
# 8                         Duplicity
# 9                       Rock'n Roll
# 10                    A Close Shave
# 11                    Andrei Rublev
# 12                          Harriet
# 13                Diary of the Dead
# 14               Testament of Youth
# 15     History of the World: Part I
# 16                All That Glitters
# 17                      Slumberland
# 18                            Hours
# 19                         Raw Deal
# Name: title, dtype: object

# %%
df_movies.shape
# Out:
# (5000, 27)

# %%
df_movies.info
# Out:
# <bound method DataFrame.info of           id                title  vote_average  vote_count    status  \
# 0     659959         Summer of 85         7.408         714  Released
# 1     175574           Free Birds         5.862         714  Released
# 2       9573           Blood Work         6.156         712  Released
# 3       5544  Hiroshima Mon Amour         7.777         712  Released
# 4       5902     A Bridge Too Far         7.222         712  Released
# ...      ...                  ...           ...         ...       ...
# 4995  321769             Deep Web         6.764         256  Released
# 4996   16729           Don't Move         6.969         256  Released
# 4997  158990           Wrong Cops         6.152         256  Released
# 4998  486078          Il vegetale         5.700         256  Released
# 4999  919573         The Innocent         6.895         256  Released
#
#      release_date    revenue  runtime  adult  \
# 0      2020-07-14    3600000      101  False
# 1      2013-10-30  110000000       91  False
# 2      2002-08-09   31794718      110  False
# 3      1959-06-10       3193       92  False
# 4      1977-06-15   50750000      175  False
# ...           ...        ...      ...    ...
# 4995   2015-03-15          0       89  False
# 4996   2004-03-12   11837022      125  False
# 4997   2013-12-18          0       83  False
# 4998   2018-01-18    8475827       84  False
# 4999   2022-10-12    5175806       95  False
#
#                          backdrop_path  ...                       poster_path  \
# 0     /oq1AkrBDj8hRVJqC2NDFT5R1NEa.jpg  ...  /rkJKDC5gYrPXQx9IqNaUhSb3beC.jpg
# 1     /bYCYL5mVX4unStJy34wWuofVq2O.jpg  ...  /gnSU2wUBq2gTkBEkxY8C1d1fXAQ.jpg
# 2     /6Jatq6wjJ4c2YbPkE5e5VzukEI2.jpg  ...  /A6wWJkIREagRWFNu3YotID3n9aW.jpg
# 3     /nHmxbmwGmbY6p5i5Soal4ZJNrTq.jpg  ...  /adLWFW0JC8f3wjhnfBnHlf85Poh.jpg
# 4     /26feWH2NF8XqxuMzfkJTp9T5dfQ.jpg  ...  /lszOk3Xmh7qpLaM9J4K9E6ADLk1.jpg
# ...                                ...  ...                               ...
# 4995  /ayfUwTMNSYcra3IfYhP4Et8iRPb.jpg  ...  /cHuh9nIPSNQQzcGmuTd9lqnfvY6.jpg
# 4996  /obZ3HXsiIhZtfCUBgvzBXOYfOhE.jpg  ...  /o5kErZoLG5eAQ5IqZxUoIzNmlJ1.jpg
# 4997  /gbjt7NvOtxTEGT3HZ2XZBoUY4TB.jpg  ...  /oTGY0n5MFueHv7GP1P9aPhuR11I.jpg
# 4998  /5B3L9nj96B2ZWnTucylDiE3V1QL.jpg  ...  /mI383Fhgvko8WzgjSDlplDHmro8.jpg
# 4999  /b4aXVjEH4PoMxubmpowanfdaVO7.jpg  ...  /e0Hhtzg2bffy1PxzM1Wv8VF4ca9.jpg
#
#                                                 tagline  \
# 0                                                   NaN
# 1                               Hang On To Your Nuggets
# 2        He's a heartbeat away from catching the killer
# 3     From the measureless depths of a woman's emoti...
# 4     Out of the sky comes the screen's most incredi...
# ...                                                 ...
# 4995                 The crime saga of the digital age.
# 4996                                                NaN
# 4997                                                NaN
# 4998                                                NaN
# 4999                                                NaN
#
#                          genres  \
# 0                Romance, Drama
# 1     Animation, Comedy, Family
# 2               Thriller, Crime
# 3       Drama, History, Romance
# 4           Drama, History, War
# ...                         ...
# 4995                Documentary
# 4996             Drama, Romance
# 4997     Comedy, Crime, Mystery
# 4998                     Comedy
# 4999     Comedy, Crime, Romance
#
#                                    production_companies  \
# 0                   Mandarin Production, SCOPE Pictures
# 1            Reel FX Creative Studios, Relativity Media
# 2            Malpaso Productions, Warner Bros. Pictures
# 3     Argos Films, Como Films, Daiei Film, Pathé Ove...
# 4          United Artists, Joseph E. Levine Productions
# ...                                                 ...
# 4995  Trouper, BOND/360, Zipper Bros Films, Exhibit ...
# 4996               Cineritmo, Alquimia Cinema, Cattleya
# 4997  Timwe, Realitism Films, CTB Film Company, Rubb...
# 4998           The Walt Disney Company Italia, 3Zero2Tv
# 4999  Les Films des Tournelles, ARTE, Auvergne-Rhône...
#
#                            production_countries  \
# 0                                        France
# 1                      United States of America
# 2                      United States of America
# 3                                 France, Japan
# 4      United Kingdom, United States of America
# ...                                         ...
# 4995                   United States of America
# 4996               United Kingdom, Italy, Spain
# 4997  Belgium, France, United States of America
# 4998                                      Italy
# 4999                                     France
#
#                            spoken_languages  \
# 0                           French, English
# 1                                   English
# 2                          English, Spanish
# 3                 English, French, Japanese
# 4     English, Dutch, Polish, German, Latin
# ...                                     ...
# 4995                                English
# 4996                                Italian
# 4997                                English
# 4998                                Italian
# 4999                                 French
#
#                                                keywords  \
# 0     based on novel or book, sailing, normandy, fra...
# 1     holiday, freedom, thanksgiving, duringcreditss...
# 2     based on novel or book, heart, police, housebo...
# 3     new love, france, atomic bomb, return, lover, ...
# 4     mission, army, allies, world war ii, netherlan...
# ...                                                 ...
# 4995  politics, war on drugs, internet, drugs, crimi...
# 4996                                                NaN
# 4997                                                NaN
# 4998                      job seeking, graduate student
# 4999  prison, wedding, widower, lyon france, caviar ...
#
#                                             description             directors  \
# 0     When 16-year-old Alexis capsizes off the coast...         François Ozon
# 1     A pair of turkeys discover a time machine and ...         Jimmy Hayward
# 2     Still recovering from a heart transplant, reti...        Clint Eastwood
# 3     A French actress filming an anti-war film in H...         Alain Resnais
# 4     Operation Market Garden, September 1944: The A...  Richard Attenborough
# ...                                                 ...                   ...
# 4995  A feature documentary that explores the rise o...           Alex Winter
# 4996  A destitute woman (Cruz) becomes involved with...    Sergio Castellitto
# 4997  A group of bad cops look to dispose of a body ...       Quentin Dupieux
# 4998  Young, newly graduated and unemployed Fabio tr...     Gennaro Nunziante
# 4999  When Abel learns that his mother is about to m...          Louis Garrel
#
#                                         main_characters
# 0     Félix Lefebvre, Benjamin Voisin, Philippine Velge
# 1              Woody Harrelson, Owen Wilson, Dan Fogler
# 2         Clint Eastwood, Jeff Daniels, Anjelica Huston
# 3            Emmanuelle Riva, Eiji Okada, Stella Dassas
# 4         Sean Connery, Ryan O&apos;Neal, Michael Caine
# ...                                                 ...
# 4995    Ross Ulbricht, James Chaparro, Nicolas Christin
# 4996  Penélope Cruz, Sergio Castellitto, Claudia Gerini
# 4997           Mark Burnham, Eric Judor, Agnes Bruckner
# 4998    Luca Zingaretti, Tommaso Basili, Paola Calliari
# 4999          Louis Garrel, Roschdy Zem, Noémie Merlant
#
# [5000 rows x 27 columns]>

# %%
df_movies.describe()
# Out:
#                  id  vote_average   vote_count       revenue      runtime  \
# count  5.000000e+03   5000.000000  5000.000000  5.000000e+03  5000.000000
# mean   2.026620e+05      6.492086   424.095400  1.073562e+07   101.320800
# std    2.544705e+05      0.815846   128.003294  2.771883e+07    23.115881
# min    2.000000e+00      2.098000   256.000000  0.000000e+00     0.000000
# 25%    1.160575e+04      5.961500   312.000000  0.000000e+00    91.000000
# 50%    4.118600e+04      6.515000   398.000000  9.011700e+04   100.000000
# 75%    3.820468e+05      7.091250   518.000000  1.084960e+07   111.000000
# max    1.140066e+06      8.550000   714.000000  7.425000e+08   366.000000
#
#              budget   popularity
# count  5.000000e+03  5000.000000
# mean   7.190641e+06    16.791120
# std    1.383037e+07    56.802788
# min    0.000000e+00     0.600000
# 25%    0.000000e+00    10.129000
# 50%    0.000000e+00    12.913500
# 75%    9.000000e+06    16.138000
# max    1.500000e+08  2680.593000

# %%
# Select relevant columns for analysis
columns = ['runtime', 'budget', 'original_language', 'genres', 'production_companies', 'vote_average']

# Extract relevant data
relevant_data = df_movies[columns]

# %%
relevant_data
# Out:
#       runtime    budget original_language                     genres  \
# 0         101   6900000                fr             Romance, Drama
# 1          91  55000000                en  Animation, Comedy, Family
# 2         110  50000000                en            Thriller, Crime
# 3          92         0                fr    Drama, History, Romance
# 4         175  22000000                en        Drama, History, War
# ...       ...       ...               ...                        ...
# 4995       89         0                en                Documentary
# 4996      125         0                it             Drama, Romance
# 4997       83         0                en     Comedy, Crime, Mystery
# 4998       84   8166084                it                     Comedy
# 4999       95   4000000                fr     Comedy, Crime, Romance
#
#                                    production_companies  vote_average
# 0                   Mandarin Production, SCOPE Pictures         7.408
# 1            Reel FX Creative Studios, Relativity Media         5.862
# 2            Malpaso Productions, Warner Bros. Pictures         6.156
# 3     Argos Films, Como Films, Daiei Film, Pathé Ove...         7.777
# 4          United Artists, Joseph E. Levine Productions         7.222
# ...                                                 ...           ...
# 4995  Trouper, BOND/360, Zipper Bros Films, Exhibit ...         6.764
# 4996               Cineritmo, Alquimia Cinema, Cattleya         6.969
# 4997  Timwe, Realitism Films, CTB Film Company, Rubb...         6.152
# 4998           The Walt Disney Company Italia, 3Zero2Tv         5.700
# 4999  Les Films des Tournelles, ARTE, Auvergne-Rhône...         6.895
#
# [5000 rows x 6 columns]

# %% [markdown]
# # Distribution Analysis

# %% [markdown]
# ## Histogram of Runtime

# %%
sns.histplot(relevant_data['runtime'], bins=30, kde=True)
plt.title('Distribution of Movie Runtimes')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # EDA
# ## Corelation Analysis

# %%
correlation = relevant_data['runtime'].corr(relevant_data['vote_average'])

print(f"Correlation between runtime and vote_average: {correlation}")
# Out:
# Correlation between runtime and vote_average: 0.15738207438910665

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=relevant_data['runtime'], y=relevant_data['vote_average'])
# Add title and labels
plt.title('Relationship Between Movie Runtime and Vote Average')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Vote Average')
plt.grid(True)

# Show the plot
plt.show()

# %%
correlation = relevant_data['budget'].corr(relevant_data['vote_average'])

print(f"Correlation between budget and vote_average: {correlation}")
# Out:
# Correlation between budget and vote_average: -0.21788469638765692

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=relevant_data['budget'], y=relevant_data['vote_average'])
# Add title and labels
plt.title('Relationship Between Movie Budget and Vote Average')
plt.xlabel('Budget')
plt.ylabel('Vote Average')
plt.grid(True)

# Show the plot
plt.show()
